# %% [markdown]
# **EXPERIMENT 2**
# ---
# *   Data Preprocessing-Cleaning the data set using data set obtained from UCI ML repository

# %% [markdown]
# 1. **Data Collection and loading of data**

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv('student3.csv')
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %% [markdown]
# #**2. Data Inspection**

# %%
df.head()
df.info()
df.isnull()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 768.0+ bytes
#             roll     marks         age
# count  16.000000  14.000000  14.000000
# mean    8.062500  66.967143  20.785714
# std     4.327721   9.640749   1.311404
# min     1.000000  56.750000  19.000000
# 25%     4.750000  59.440000  20.000000
# 50%     8.500000  64.395000  20.500000
# 75%    11.250000  73.005000  21.750000
# max    15.000000  88.450000  23.000000

# %%
df.dropna()
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 15    15  shalini    TE   63.45  20.0

# %% [markdown]
# #**3. Handling Missing values**

# %%
df['marks '].fillna(df['marks '].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     66.967143
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 9     56.750000
# 10    78.660000
# 11    66.967143
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks , dtype: float64

# %%
df['age'].fillna(df['age'].mode()[0])
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df.dropna()
# Out:
#      Age_18.0  Age_19.0  Age_20.0  Age_21.0  Age_22.0  Age_23.0  Age_24.0  \
# 0       False      True     False     False     False     False     False
# 1       False     False     False     False     False     False     False
# 2       False     False     False     False     False     False     False
# 3       False     False     False     False     False     False     False
# 4       False      True     False     False     False     False     False
# ..        ...       ...       ...       ...       ...       ...       ...
# 395     False     False     False     False     False     False     False
# 396     False     False     False     False     False     False     False
# 397     False     False     False     False     False     False     False
# 398     False     False     False     False     False     False     False
# 399     False     False     False     False     False     False     False
#
#      Age_25.0  Age_26.0  Age_27.0  ...  User ID_15810944  User ID_15811177  \
# ...

# %% [markdown]
# # **4. Transforming Data**

# %%
df = pd.read_csv('Social_Network_Ads.csv')
x = df[['Age','EstimatedSalary']]
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
df
# Out:
#       User ID  Gender  EstimatedSalary  Purchased  Age_18.0  Age_19.0  \
# 0    15624510    Male          19000.0          0     False      True
# 1    15810944    Male          20000.0          0     False     False
# 2    15668575  Female          43000.0          0     False     False
# 3    15603246  Female          57000.0          0     False     False
# 4    15804002    Male          76000.0          0     False      True
# ..        ...     ...              ...        ...       ...       ...
# 395  15691863  Female          41000.0          1     False     False
# 396  15706071    Male          23000.0          1     False     False
# 397  15654296  Female          20000.0          1     False     False
# 398  15755018    Male          33000.0          0     False     False
# 399  15594041  Female          36000.0          1     False     False
#
#      Age_20.0  Age_21.0  Age_22.0  Age_23.0  ...  Age_51.0  Age_52.0  \
# ...

# %%
df = pd.get_dummies(df, columns=['Purchased'])
df
# Out:
#      Age_18.0  Age_19.0  Age_20.0  Age_21.0  Age_22.0  Age_23.0  Age_24.0  \
# 0       False      True     False     False     False     False     False
# 1       False     False     False     False     False     False     False
# 2       False     False     False     False     False     False     False
# 3       False     False     False     False     False     False     False
# 4       False      True     False     False     False     False     False
# ..        ...       ...       ...       ...       ...       ...       ...
# 395     False     False     False     False     False     False     False
# 396     False     False     False     False     False     False     False
# 397     False     False     False     False     False     False     False
# 398     False     False     False     False     False     False     False
# 399     False     False     False     False     False     False     False
#
#      Age_25.0  Age_26.0  Age_27.0  ...  User ID_15810944  User ID_15811177  \
# ...

# %% [markdown]
# #**4. Data Integration**

# %%
df_2 = pd.read_csv('Student_5.csv')
df_3 = pd.read_csv('student3.csv')

# %%
merged_data = pd.merge(df_2, df_3, on='roll')
merged_data
# Out:
#     roll   name_x class_x  marks _x  age_x   name_y class_y  marks _y  age_y
# 0      1     anil      TE     56.77   22.0     anil      TE     56.77   22.0
# 1      2     amit      TE     59.77   21.0     amit      TE     59.77   21.0
# 2      3   aniket      BE     76.88   19.0   aniket      BE     76.88   19.0
# 3      4  ajinkya      TE     69.66   20.0  ajinkya      TE     69.66   20.0
# 4      5     asha      TE     63.28    NaN     asha      TE     63.28    NaN
# 5      6   ayesha      BE       NaN   20.0   ayesha      BE       NaN   20.0
# 6      7     amar      BE     65.34   19.0     amar      BE     65.34   19.0
# 7      7     amar      BE     65.34   19.0     amar      BE     65.34   19.0
# 8      8    Amita      be    168.33   23.0    Amita      be     68.33   23.0
# 9      9     amol      TE     56.75   20.0     amol      TE     56.75   20.0
# 10     9     amol      TE     56.75   20.0     amol      TE     56.75   20.0
# ...
