# %% [markdown]
# # **EXPRIMENT 1:**
# Loading and merging data sets using UCI ML repository.
#
# *   Loading
# *   Merging
# *   Flitering
# *   Sampeling

# %% [markdown]
# *   **Merging and Loading Method**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets into dataframes
df1 = pd.read_csv("spotify_tracks1.csv")
df2 = pd.read_csv("test.csv")

# Merge datasets
merged_df = pd.merge(df1, df2, on='Popularity')  # Replace 'common_column' with the actual common column name

# Optionally, handle missing data
# merged_df = merged_df.dropna()  # Example: drop rows with NaN values

# Print merged dataframe or do further analysis
print(merged_df.head())
# Out:
#                        id      name     genre        artists album  \
# 0  7kr3xZk4yb3YSZ4VFtg2Qt  Acoustic  acoustic  Billy Raffoul  1975
# 1  7kr3xZk4yb3YSZ4VFtg2Qt  Acoustic  acoustic  Billy Raffoul  1975
# 2  7kr3xZk4yb3YSZ4VFtg2Qt  Acoustic  acoustic  Billy Raffoul  1975
# 3  7kr3xZk4yb3YSZ4VFtg2Qt  Acoustic  acoustic  Billy Raffoul  1975
# 4  7kr3xZk4yb3YSZ4VFtg2Qt  Acoustic  acoustic  Billy Raffoul  1975
#
#    Popularity  duration_ms  explicit         Artist Name  \
# 0          58       172199     False              T. Rex
# 1          58       172199     False  Taking Back Sunday
# 2          58       172199     False           The Hives
# 3          58       172199     False         The Bravery
# 4          58       172199     False          Josh Fudge
#
#                      Track Name  ...  loudness  mode  speechiness  \
# 0                 Cosmic Dancer  ...    -8.089     1       0.0600
# 1  A Decade Under The Influence  ...    -4.729     1       0.0765
# 2               Walk Idiot Walk  ...    -3.934     1       0.1030
# 3                       Believe  ...    -3.369     1       0.0459
# 4                     FEEL LIKE  ...    -7.090     1       0.0544
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.01170          0.006010     0.189    0.718  156.047
# 1       0.00929               NaN     0.106    0.607  156.031
# 2       0.00386          0.005750     0.582    0.684  146.318
# 3       0.00501          0.000002     0.113    0.517  166.137
# 4       0.10900          0.201000     0.591    0.695  104.977
#
#    duration_in min/ms  time_signature
# 0            266533.0               4
# 1            247760.0               4
# 2            211813.0               4
# 3            226347.0               4
# 4            188143.0               4
#
# [5 rows x 23 columns]

# %% [markdown]
# *   **Filtering Method**

# %%
merged_df.filter(["name","genre","artists","album","Popularity","duration_ms","explicit","Artist Name","Track Name","loudness","mode","speechiness","acousticness",
                  "instrumentalness","liveness","valence","tempo","duration_in min/ms","time_signature"])
# Out:
#                                            name     genre  \
# 0                                      Acoustic  acoustic
# 1                                      Acoustic  acoustic
# 2                                      Acoustic  acoustic
# 3                                      Acoustic  acoustic
# 4                                      Acoustic  acoustic
# ...                                         ...       ...
# 576433                                  Starboy      punk
# 576434                                  Starboy      punk
# 576435                                  Starboy      punk
# 576436  Clean Baby Sleep White Noise (Loopable)     sleep
# 576437  Clean Baby Sleep White Noise (Loopable)     sleep
#
#                                                   artists  \
# 0                                           Billy Raffoul
# 1                                           Billy Raffoul
# 2                                           Billy Raffoul
# 3                                           Billy Raffoul
# 4                                           Billy Raffoul
# ...                                                   ...
# 576433                              The Weeknd, Daft Punk
# 576434                              The Weeknd, Daft Punk
# 576435                              The Weeknd, Daft Punk
# 576436  Dream Supplier, Baby Sleeps, Background White ...
# 576437  Dream Supplier, Baby Sleeps, Background White ...
#
#                                      album  Popularity  duration_ms  explicit  \
# 0                                     1975          58       172199     False
# 1                                     1975          58       172199     False
# 2                                     1975          58       172199     False
# 3                                     1975          58       172199     False
# 4                                     1975          58       172199     False
# ...                                    ...         ...          ...       ...
# 576433                             Starboy          84       230453      True
# 576434                             Starboy          84       230453      True
# 576435                             Starboy          84       230453      True
# 576436  Best White Noise For Sleeping Baby          88       142222     False
# 576437  Best White Noise For Sleeping Baby          88       142222     False
#
#                Artist Name                           Track Name  loudness  \
# 0                   T. Rex                        Cosmic Dancer    -8.089
# 1       Taking Back Sunday         A Decade Under The Influence    -4.729
# 2                The Hives                      Walk Idiot Walk    -3.934
# 3              The Bravery                              Believe    -3.369
# 4               Josh Fudge                            FEEL LIKE    -7.090
# ...                    ...                                  ...       ...
# 576433       Mother Mother                              Hayloft    -2.666
# 576434       Glass Animals                           Heat Waves    -6.900
# 576435         Tame Impala           The Less I Know The Better    -4.083
# 576436        Trippie Redd  Miss The Rage (feat. Playboi Carti)    -5.616
# 576437       Ariana Grande                                34+35    -6.476
#
#         mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0          1       0.0600       0.01170          0.006010    0.1890    0.718
# 1          1       0.0765       0.00929               NaN    0.1060    0.607
# 2          1       0.1030       0.00386          0.005750    0.5820    0.684
# 3          1       0.0459       0.00501          0.000002    0.1130    0.517
# 4          1       0.0544       0.10900          0.201000    0.5910    0.695
# ...      ...          ...           ...               ...       ...      ...
# 576433     0       0.0728       0.00475          0.000162    0.4220    0.490
# 576434     1       0.0944       0.44000          0.000007    0.0921    0.531
# 576435     1       0.0284       0.01150          0.006780    0.1670    0.785
# 576436     1       0.1210       0.01440               NaN    0.8470    0.369
# 576437     1       0.0940       0.23700               NaN    0.2480    0.485
#
#           tempo  duration_in min/ms  time_signature
# 0       156.047       266533.000000               4
# 1       156.031       247760.000000               4
# 2       146.318       211813.000000               4
# 3       166.137       226347.000000               4
# 4       104.977       188143.000000               4
# ...         ...                 ...             ...
# 576433   95.975       181680.000000               4
# 576434   80.870            3.980083               4
# 576435  116.879       216320.000000               4
# 576436   77.005       236883.000000               4
# 576437  109.978       173711.000000               4
#
# [576438 rows x 19 columns]

# %% [markdown]
# *   **Sampling Method**

# %%
rows = merged_df.sample(frac =.00001)
rows
# Out:
#                             id                             name       genre  \
# 360824  3RZMzCvYsmJ0u2ioKTOsmJ  Honky Tonk Women - Mono Version  honky-tonk
# 116339  6ZIxazB6VpBANICYSNU9M9                            Shiny   punk-rock
# 77378   5JkhaJ8e1umEpQge45tY6T    BRAZILIAN DANÇA PHONK - Remix      brazil
# 235917  4uEDBem2944dhk1GhTCiEx                 Tango del Pecado       tango
# 281722  7xoxBDDv0CTZuVARxQ7I2F                      Havar Havar  psych-rock
# 177620  2so6WzyodEY32OPAgsx1YD                           Cinema      french
#
#                                artists  \
# 360824              The Rolling Stones
# 116339  Punk Rock Factory, Benji Webbe
# 77378     6YNTHMANE, RXDXVIL, Kordhell
# 235917                        Calle 13
# 281722                Kourosh Yaghmaei
# 177620           French Braids, Tailor
#
#                                                     album  Popularity  \
# 360824                              Hot Rocks (1964-1971)          50
# 116339                                A Whole New Wurst 2          25
# 77378                       BRAZILIAN DANÇA PHONK (Remix)          45
# 235917                              Residente o Visitante          28
# 281722  Back From The Brink: Pre-Revolution Psychedeli...          32
# 177620                                             Cinema          24
#
#         duration_ms  explicit                       Artist Name  \
# 360824       179386     False                      Lewis Watson
# 116339       140439     False                              CARM
# 77378         78461      True                    Travis Denning
# 235917       253413     False  Claude Debussy, Linos Piano Trio
# 281722       225880     False                     The Treatment
# 177620       211323     False                     Kishore Kumar
#
#                                                Track Name  ...  loudness  \
# 360824                    little light - acoustic version  ...    -8.114
# 116339                                         Soft Night  ...   -10.977
# 77378                                     Call It Country  ...    -3.551
# 235917  Prélude à l'après-midi d'un Faune, L. 86 (Arr....  ...   -27.339
# 281722                                           Rat Race  ...    -6.563
# 177620                             Meet Na Mila Re Man Ka  ...   -12.688
#
#         mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 360824     1       0.0341      0.685000               NaN    0.1470   0.5150
# 116339     1       0.0327      0.929000          0.907000    0.2720   0.1330
# 77378      1       0.0836      0.010400               NaN    0.2560   0.6480
# 235917     1       0.0469      0.979000          0.689000    0.1040   0.0337
# 281722     1       0.0351      0.000069          0.000409    0.0661   0.6410
# 177620     1       0.0707      0.832000          0.000038    0.1260   0.7810
#
#           tempo  duration_in min/ms  time_signature
# 360824  119.856       256415.000000               4
# 116339  138.009       239267.000000               4
# 77378   127.065       151148.000000               4
# 235917   77.179           10.482833               3
# 281722  133.997       204440.000000               4
# 177620   81.663            4.338450               4
#
# [6 rows x 23 columns]
