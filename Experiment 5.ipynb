# %% [markdown]
# # EXPERIMENT 5
# * Line Chart: Created using sns.lineplot with markers (marker='o').
# * Labels: Added with plt.xlabel, plt.ylabel, and plt.title.
# * Legend: Added with plt.legend().
# * Count Plot: Created using sns.countplot.

# %% [markdown]
# * **Importing nesseary libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('mtcars.csv')

# %% [markdown]
# * **Line Chart with Labels, Legends, and Markers**

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=df['gear'], y=df['hp'], data=df, marker='o', label='Line with Markers', color='blue')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Chart with Labels, Legends, and Markers')
plt.legend()

plt.show()

# %% [markdown]
#  * **Count Plot**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=df['mpg'], data=df, palette='viridis')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count Plot')

plt.show()
# Out:
# <ipython-input-17-bbb73425574b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['mpg'], data=df, palette='viridis')
